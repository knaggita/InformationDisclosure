# %%
import sys, os, importlib
sys.path.append('../')

import scripts.analytics
import scripts.algorithms

f = sys.stdout
sys.stdout = open(os.devnull, 'w')

importlib.reload(scripts.analytics)
importlib.reload(scripts.algorithms)

import numpy as np
import pandas as pd

sys.stdout.close()
sys.stdout = f

# %%
dsetname = "studentportuguese"
dsetnamex = "Portuguese"

d = 30

######
graphsx = np.load("../graphs/"+dsetname+"_thresh_random.npy", allow_pickle=True)

# %% [markdown]
# ## Info on the graphs

# %%
######
randomgraphsinfo = pd.read_csv("../graphs/studentportuguese_thresh_graphsummary.npy")
randomgraphsinfo
# Out:
#                Dataset (d)     r    n   m  #+ves  #-ves   avg LHSd  avg LHS+d  \
# 0   Student-portguese (30)   4.0  224   6      5      1   0.035714   0.031250
# 1   Student-portguese (30)   4.5  224  22     13      9   0.214286   0.165179
# 2   Student-portguese (30)   5.0  224  32     18     14   0.665179   0.540179
# 3   Student-portguese (30)   5.5  224  39     20     19   1.500000   1.044643
# 4   Student-portguese (30)   6.0  224  44     20     24   3.433036   2.129464
# 5   Student-portguese (30)   6.5  224  48     21     27   7.116071   4.312500
# 6   Student-portguese (30)   7.0  224  49     21     28  12.691964   7.169643
# 7   Student-portguese (30)   7.5  224  50     22     28  19.758929  10.526786
# 8   Student-portguese (30)   8.0  224  50     22     28  27.272321  13.718750
# 9   Student-portguese (30)   8.5  224  50     22     28  34.062500  16.522321
# 10  Student-portguese (30)   9.0  224  50     22     28  39.946429  18.687500
# 11  Student-portguese (30)   9.5  224  50     22     28  44.290179  20.156250
# 12  Student-portguese (30)  10.0  224  50     22     28  47.058036  20.986607
#
#     avg LHS-d    avg RHSd  avg overlap  avg overlap+  avg overlap-  only+Ns  \
# 0    0.004464    1.333333     0.001810      0.001810      0.000000        4
# 1    0.049107    2.181818     0.011933      0.011592      0.000341       18
# 2    0.125000    4.656250     0.059369      0.057328      0.002041       32
# 3    0.455357    8.615385     0.146890      0.122548      0.024342       30
# 4    1.303571   17.477273     0.470476      0.328889      0.141587       26
# 5    2.803571   33.208333     1.655986      1.134377      0.521610       15
# 6    5.522321   58.020408     4.525781      2.862906      1.662874        6
# 7    9.232143   88.520000     9.798838      5.790984      4.007854        4
# 8   13.553571  122.180000    17.218596      9.356865      7.861731        1
# 9   17.540179  152.600000    25.435338     13.162676     12.272662        0
# 10  21.258929  178.960000    33.531670     16.478980     17.052691        0
# 11  24.133929  198.420000    40.160474     18.913237     21.247237        0
# 12  26.071429  210.820000    44.693185     20.255766     24.437420        0
#
#     only-Ns  emptyNs  uni+  graphID
# 0         0      219     2        0
# 1         6      196     0        1
# 2         8      169     0        2
# 3        28      129     0        3
# 4        40       77     0        4
# 5        29       41     0        5
# 6        22       20     0        6
# 7        16        7     0        7
# 8         7        3     0        8
# 9         3        1     0        9
# 10        2        0     0       10
# 11        0        0     0       11
# 12        0        0     1       12

# %% [markdown]
# ## Learning

# %%
summary_dfx = scripts.algorithms.learn_greedy(datagraphs=graphsx, 
                                               dim=d,
                                               savedname=dsetname,
                                               thresh=True)

summary_dfx.to_csv("./ls_results/"+dsetname+"_learn_results_thresh.csv", index=False)
summary_dfx.head(10)
# Out:
#    K                 dataset  graphid    r    n   m  tr_utility  ts_utility  \
# 0  1  studentportuguese (30)        0  4.0  224   6    3.440000    1.453333
# 1  2  studentportuguese (30)        0  4.0  224   6    3.440000    1.453333
# 2  3  studentportuguese (30)        0  4.0  224   6    3.440000    1.453333
# 3  4  studentportuguese (30)        0  4.0  224   6    3.440000    1.453333
# 4  5  studentportuguese (30)        0  4.0  224   6    3.440000    1.453333
# 5  1  studentportuguese (30)        1  4.5  224  22   15.144167    6.190000
# 6  2  studentportuguese (30)        1  4.5  224  22   15.450000    6.265000
# 7  3  studentportuguese (30)        1  4.5  224  22   15.450000    6.265000
# 8  4  studentportuguese (30)        1  4.5  224  22   15.450000    6.265000
# 9  5  studentportuguese (30)        1  4.5  224  22   15.450000    6.265000
#
#    tr_size  ts_size  ...  ts_only-Ns  tr_empty_adj  ts_empty_adj   tr_perf1  \
# 0    156.0     68.0  ...        0.00        152.56         66.44  100.00000
# 1    156.0     68.0  ...        0.00        152.56         66.44  100.00000
# 2    156.0     68.0  ...        0.00        152.56         66.44  100.00000
# 3    156.0     68.0  ...        0.00        152.56         66.44  100.00000
# 4    156.0     68.0  ...        0.00        152.56         66.44  100.00000
# 5    156.0     68.0  ...        2.02        136.57         59.43   98.07142
# 6    156.0     68.0  ...        2.02        136.57         59.43  100.00000
# 7    156.0     68.0  ...        2.02        136.57         59.43  100.00000
# 8    156.0     68.0  ...        2.02        136.57         59.43  100.00000
# 9    156.0     68.0  ...        2.02        136.57         59.43  100.00000
#
#    ts_perf1  tr_perf2  ts_perf2  tr_perf3  ts_perf3  greedyTime
# 0  82.13888   2.20504   2.13736  68.00000  21.33344    0.003818
# 1  82.13888   2.20504   2.13736  68.00000  21.33344    0.005446
# 2  82.13888   2.20504   2.13736  68.00000  21.33344    0.005745
# 3  82.13888   2.20504   2.13736  68.00000  21.33344    0.005345
# 4  82.13888   2.20504   2.13736  68.00000  21.33344    0.005987
# 5  94.69103   9.70778   9.10290  88.04177  56.45837    0.013353
# 6  95.79004   9.90346   9.21322  98.00000  62.70837    0.025361
# 7  95.79004   9.90346   9.21322  98.00000  62.70837    0.036815
# 8  95.79004   9.90346   9.21322  98.00000  62.70837    0.035425
# 9  95.79004   9.90346   9.21322  98.00000  62.70837    0.035185
#
# [10 rows x 21 columns]

# %% [markdown]
# ## Plots

# %%
######### exclude: no neighbors and exclusively neg neighbors
scripts.analytics.learnsetting_plot(summary_res=summary_dfx,
                  thresh=True, 
                  perfv="perf1", 
                  save_as="./ls_results/figures/"+dsetname+"_learn_both_results_thresh_perf1.pdf")

######### exclude: none
scripts.analytics.learnsetting_plot(summary_res=summary_dfx,
                  thresh=True, 
                  perfv="perf2", 
                  save_as="./ls_results/figures/"+dsetname+"_learn_both_results_thresh_perf2.pdf")

######### exclude: no neighbors and exclusively neg/pos neighbors
scripts.analytics.learnsetting_plot(summary_res=summary_dfx,
                  thresh=True, 
                  perfv="perf3", 
                  save_as="./ls_results/figures/"+dsetname+"_learn_both_results_thresh_perf3.pdf")
